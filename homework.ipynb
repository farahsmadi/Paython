# %%
capitals={"Palestine":"Jerusalem","Japan":"Tokyo","Egypt":"Cairo","Jordan":"Amman","UAE":"Dubai","sudan":"khartoom","Marakesh":"Rebat","India":"New Delhi","Yaman":"Sanaa"}
print(capitals["Palestine"])
# Out:
# Jerusalem

# %%
cap={"Tounis":"Tounis","Kuwait":"Kuwait"}  
capitals.update(cap)

# %%
capitals
# Out:
# {'Egypt': 'Cairo',
#  'India': 'New Delhi',
#  'Japan': 'Tokyo',
#  'Jordan': 'Amman',
#  'Kuwait': 'Kuwait',
#  'Marakesh': 'Rebat',
#  'Palestine': 'Jerusalem',
#  'Tounis': 'Tounis',
#  'UAE': 'Dubai',
#  'Yaman': 'Sanaa',
#  'sudan': 'khartoom'}

# %%
for key,value in capitals.items():
    print(key,value)
# Out:
# Palestine Jerusalem
# Japan Tokyo
# Egypt Cairo
# Jordan Amman
# UAE Dubai
# sudan khartoom
# Marakesh Rebat
# India New Delhi
# Yaman Sanaa
# Tounis Tounis
# Kuwait Kuwait

# %%
capitals_bycapital = {capitals[key]: key for key in capitals}

# %%
capitals_bycapital
# Out:
# {'Amman': 'Jordan',
#  'Cairo': 'Egypt',
#  'Dubai': 'UAE',
#  'Jerusalem': 'Palestine',
#  'Kuwait': 'Kuwait',
#  'New Delhi': 'India',
#  'Rebat': 'Marakesh',
#  'Sanaa': 'Yaman',
#  'Tokyo': 'Japan',
#  'Tounis': 'Tounis',
#  'khartoom': 'sudan'}

# %%
c1=["Palestine","Japan","Egypt","Jordan","UAE","sudan","Marakesh","India","Yaman"]
c1
# Out:
# ['Palestine',
#  'Japan',
#  'Egypt',
#  'Jordan',
#  'UAE',
#  'sudan',
#  'Marakesh',
#  'India',
#  'Yaman']

# %%
c2= ["Jerusalem","Tokyo","Cairo","Amman","Dubai","khartoom","Rebat","New Delhi","Sanaa"]
c2
# Out:
# ['Jerusalem',
#  'Tokyo',
#  'Cairo',
#  'Amman',
#  'Dubai',
#  'khartoom',
#  'Rebat',
#  'New Delhi',
#  'Sanaa']

# %%
dict(zip(c1, c2))
# Out:
# {'Egypt': 'Cairo',
#  'India': 'New Delhi',
#  'Japan': 'Tokyo',
#  'Jordan': 'Amman',
#  'Marakesh': 'Rebat',
#  'Palestine': 'Jerusalem',
#  'UAE': 'Dubai',
#  'Yaman': 'Sanaa',
#  'sudan': 'khartoom'}

# %%
c={key:value for key in c1 for value in c2}
print(c)
# Out:
# {'Palestine': 'Sanaa', 'Japan': 'Sanaa', 'Egypt': 'Sanaa', 'Jordan': 'Sanaa', 'UAE': 'Sanaa', 'sudan': 'Sanaa', 'Marakesh': 'Sanaa', 'India': 'Sanaa', 'Yaman': 'Sanaa'}

# %%
s={}
for i in c1: 
    for j in c2 :
        s[i]=j

# %%
print (s)
# Out:
# {'Palestine': 'Sanaa', 'Japan': 'Sanaa', 'Egypt': 'Sanaa', 'Jordan': 'Sanaa', 'UAE': 'Sanaa', 'sudan': 'Sanaa', 'Marakesh': 'Sanaa', 'India': 'Sanaa', 'Yaman': 'Sanaa'}
